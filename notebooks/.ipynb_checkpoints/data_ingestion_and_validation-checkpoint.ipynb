# %%
import pandas as pd

# %% [markdown]
# ## Utility Functions and Variables

# %%
def pull_raw_traffic_data(file_locations):
    """
    Function for reading in the raw .xlsx file containing the traffic timeseries data
    :param file_locations: list, consisting of: locations on disk that .xlsx is stored.
    """
    # note the use of None here. It allows for reading in data from all worksheets
    # See https://pandas.pydata.org/docs/reference/api/pandas.read_excel.html for more information on pd.read_excel()
    raw = [pd.read_excel(file_location, None) for file_location in file_locations]
    # Sheet1 is a data summary worksheet in sample data file, so should be skipped
    frames = [dict[region_code] for dict in raw for region_code in dict if region_code != 'Sheet1']
    raw = pd.concat(frames)
    raw['Date'] = pd.to_datetime(raw['Date'])
    raw.set_index('Date', inplace=True)
    raw.index = pd.DatetimeIndex(raw.index.values, freq=raw.index.inferred_freq)
    asc = raw.sort_index()
    return asc

def aggregate_hostname_daily_traffic_by_month(hostname_daily_traffic):
    """
    Functions for aggregating daily traffic into monthly traffic.
    :param hostname_daily_traffic: a Pandas DataFrame that has a date Index 
        and only includes traffic from one specific hostname
    """
    hostname_daily_traffic.loc[:, 'Year'] = hostname_daily_traffic.index.year
    hostname_daily_traffic.loc[:, 'Month'] = hostname_daily_traffic.index.month
    hostname_daily_traffic.loc[:, 'Day'] = 1
    hostname_daily_traffic.loc[:, 'Date'] = pd.to_datetime(hostname_daily_traffic[['Year', 'Month', 'Day']])
    return hostname_daily_traffic.groupby('Date').agg({'Sessions':'sum', 'Pageviews':'sum'})

def apply_index_freq(data, freq):
    """
    Function for applying the correct temporal frequency to the Index of the Pandas DataFrame
    :param data: a Pandas DataFrame that has a date or datetime Index set
    :param freq: a timespan frequency string
        See https://pandas.pydata.org/pandas-docs/stable/user_guide/timeseries.html#dateoffset-objects
        for more information on allowable frequency strings
    """
    return data.asfreq(freq)

def get_hostname_data_from_df(full_file, freq, hostname):
    """
    Function for filtering out a single hostname from the full file
    :param full_file: the read-in DataFrame of the hostname .xlsx
    :param freq: the timespan frequency string for the index temporal component
    :param hostname: the hostname key code to filter upon
    """
    filtered = full_file[full_file[HOSTNAME_FIELD] == hostname]
    aggregated = aggregate_hostname_daily_traffic_by_month(filtered)
    # drop the data of the first month, since a few hostnames' first-month data is not complete
    aggregated = aggregated.iloc[1:, :]
    return apply_index_freq(aggregated, freq)

def get_all_hostnames_from_df(full_file):
    """
    Function for returning the unique list of hostnames contained within the data set.
    :param full_file:
    """
    return sorted(full_file[HOSTNAME_FIELD].unique())

# %%
DATA_PATHS = ['/opt/notebooks/datasets/NB_GA_Data_1.xlsx', '/opt/notebooks/datasets/NB_GA_Data_2.xlsx']
HOSTNAME_FIELD = 'Hostname'
SERIES_FREQ = 'MS'

# %% [markdown]
# ## operations of data ingestion

# %%
DATA_PATHS = ['/opt/notebooks/datasets/NB_GA_Data_1.xlsx', '/opt/notebooks/datasets/NB_GA_Data_2.xlsx']

# %%
raw = [pd.read_excel(data_path, None) for data_path in DATA_PATHS]

# %%
len(raw[0])
# Out:
# 5

# %%
len(raw[1])
# Out:
# 6

# %%
raw
# Out:
# [{'NB | GA | US Data':             Date Device Category            Hostname Default Channel Grouping  \
#   0     2016-11-30         desktop  www.newbalance.com                  (Other)
#   1     2016-11-30         desktop  www.newbalance.com                   Direct
#   2     2016-11-30         desktop  www.newbalance.com                  Display
#   3     2016-11-30         desktop  www.newbalance.com           Organic Search
#   4     2016-11-30         desktop  www.newbalance.com              Paid Search
#   ...          ...             ...                 ...                      ...
#   42136 2022-12-31          tablet  www.newbalance.com                    Email
#   42137 2022-12-31          tablet  www.newbalance.com           Organic Search
#   42138 2022-12-31          tablet  www.newbalance.com              Paid Search
#   42139 2022-12-31          tablet  www.newbalance.com                 Referral
#   42140 2022-12-31          tablet  www.newbalance.com                   Social
#
#          Sessions  Pageviews
#   0          5282      25091
#   1         22450     101023
#   2          7923      63387
#   3         17167     121492
#   4          8584      69990
#   ...         ...        ...
#   42136       337       1123
#   42137      1207       4687
#   42138       982       4743
#   42139        84        477
#   42140       253        421
#
#   [42141 rows x 6 columns],
#   'NB | GA | CA Data':                       Date Device Category           Hostname  \
#   0      2016-11-30 00:00:00         desktop  www.newbalance.ca
#   1      2016-11-30 00:00:00         desktop  www.newbalance.ca
#   2      2016-11-30 00:00:00         desktop  www.newbalance.ca
#   3      2016-11-30 00:00:00         desktop  www.newbalance.ca
#   4      2016-11-30 00:00:00          mobile  www.newbalance.ca
#   ...                    ...             ...                ...
#   42528  2022-12-31 00:00:00          tablet  www.newbalance.ca
#   42529  2022-12-31 00:00:00          tablet  www.newbalance.ca
#   42530  2022-12-31 00:00:00          tablet  www.newbalance.ca
#   42531  2022-12-31 00:00:00          tablet  www.newbalance.ca
#   42532  2022-12-31 00:00:00          tablet  www.newbalance.ca
#
#         Default Channel Grouping  Sessions  Pageviews
#   0                       Direct       602       6125
#   1               Organic Search       744      10161
#   2                  Paid Search       177        744
#   3                     Referral       673       4673
#   4                       Direct       283       2195
#   ...                        ...       ...        ...
#   42528                   Direct        81        357
#   42529           Organic Search       141        870
#   42530              Paid Search        11         30
#   42531                 Referral        41        316
#   42532                   Social        37        133
#
#   [42533 rows x 6 columns],
#   'NB | GA | AU Data':             Date Device Category                        Hostname  \
#   0     2016-11-30         desktop  newbalance.us4.list-manage.com
#   1     2016-11-30         desktop           www.newbalance.com.au
#   2     2016-11-30         desktop           www.newbalance.com.au
#   3     2016-11-30         desktop           www.newbalance.com.au
#   4     2016-11-30         desktop           www.newbalance.com.au
#   ...          ...             ...                             ...
#   43072 2022-12-31          tablet           www.newbalance.com.au
#   43073 2022-12-31          tablet           www.newbalance.com.au
#   43074 2022-12-31          tablet           www.newbalance.com.au
#   43075 2022-12-31          tablet           www.newbalance.com.au
#   43076 2022-12-31          tablet           www.newbalance.com.au
#
#         Default Channel Grouping  Sessions  Pageviews
#   0                     Referral        48         48
#   1                       Direct       338       1160
#   2                        Email       145        242
#   3               Organic Search       918       9861
#   4                  Paid Search       242       1595
#   ...                        ...       ...        ...
#   43072         Impact Affiliate        13         53
#   43073           Organic Search       145        717
#   43074                OzBargain         6         38
#   43075              Paid Search       277       1395
#   43076                   Social       500       2426
#
#   [43077 rows x 6 columns],
#   'NB | GA | NZ Data':                       Date Device Category              Hostname  \
#   0      2016-11-30 00:00:00         desktop  www.newbalance.co.nz
#   1      2016-11-30 00:00:00         desktop  www.newbalance.co.nz
#   2      2016-11-30 00:00:00         desktop  www.newbalance.co.nz
#   3      2016-11-30 00:00:00         desktop  www.newbalance.co.nz
#   4      2016-11-30 00:00:00         desktop  www.newbalance.co.nz
#   ...                    ...             ...                   ...
#   40125  2022-12-31 00:00:00          tablet  www.newbalance.co.nz
#   40126  2022-12-31 00:00:00          tablet  www.newbalance.co.nz
#   40127  2022-12-31 00:00:00          tablet  www.newbalance.co.nz
#   40128  2022-12-31 00:00:00          tablet  www.newbalance.co.nz
#   40129  2022-12-31 00:00:00          tablet  www.newbalance.co.nz
#
#         Default Channel Grouping  Sessions  Pageviews
#   0                      (Other)         9         18
#   1                       Direct        45         80
#   2                        Email        27         27
#   3               Organic Search        27        712
#   4                  Paid Search       116        837
#   ...                        ...       ...        ...
#   40125                    Email         2          5
#   40126           Organic Search        14         59
#   40127              Paid Search        48        200
#   40128                 Referral         4         47
#   40129                   Social        32         95
#
#   [40130 rows x 6 columns],
#   'NB | GA | JNBO Data':             Date Device Category                      Hostname  \
#   0     2016-11-01         desktop  www.joesnewbalanceoutlet.com
#   1     2016-11-01         desktop  www.joesnewbalanceoutlet.com
#   2     2016-11-01         desktop  www.joesnewbalanceoutlet.com
#   3     2016-11-01         desktop  www.joesnewbalanceoutlet.com
#   4     2016-11-01         desktop  www.joesnewbalanceoutlet.com
#   ...          ...             ...                           ...
#   49640 2022-12-31          mobile  www.joesnewbalanceoutlet.com
#   49641 2022-12-31          mobile  www.joesnewbalanceoutlet.com
#   49642 2022-12-31          mobile  www.joesnewbalanceoutlet.com
#   49643 2022-12-31          tablet  www.joesnewbalanceoutlet.com
#   49644 2022-12-31          tablet  www.joesnewbalanceoutlet.com
#
#             Default Channel Grouping  Sessions  Pageviews
#   0                        Affiliate      1951       9753
#   1      Comparison Shopping Engines      1561       4292
#   2                           Direct      3901      11704
#   3                            Email      5332      26919
#   4                   Organic Search      2731      20807
#   ...                            ...       ...        ...
#   49640                  Paid Search      4682      16516
#   49641                     Referral       260        390
#   49642                       Social       390       3121
#   49643                    Affiliate       130        130
#   49644               Organic Search       260        260
#
#   [49645 rows x 6 columns]},
#  {'Sheet1':                               Unnamed: 0       Unnamed: 1
#   0                                    NaN              NaN
#   1                             Row Labels  Sum of Sessions
#   2                   www.newbalance.co.uk         55417008
#   3                      www.newbalance.fr         29348210
#   4                      www.newbalance.es         27924792
#   ..                                   ...              ...
#   87  www.newbalance.es.googleweblight.com              245
#   88                           webproxy.to              245
#   89                         newbalance.se                0
#   90                        162.158.77.204                0
#   91                           Grand Total        187777569
#
#   [92 rows x 2 columns],
#   'NB | GA | EU + UK':                        Date Device Category           Hostname  \
#   0       2018-09-25 00:00:00         desktop   at.newbalance.eu
#   1       2018-09-25 00:00:00         desktop   at.newbalance.eu
#   2       2018-09-25 00:00:00         desktop   ee.newbalance.eu
#   3       2018-09-25 00:00:00         desktop   nl.newbalance.eu
#   4       2018-09-25 00:00:00         desktop   nl.newbalance.eu
#   ...                     ...             ...                ...
#   165193  2022-12-31 00:00:00          tablet  www.newbalance.it
#   165194  2022-12-31 00:00:00          tablet  www.newbalance.it
#   165195  2022-12-31 00:00:00          tablet  www.newbalance.pt
#   165196  2022-12-31 00:00:00          tablet  www.newbalance.pt
#   165197  2022-12-31 00:00:00          tablet  www.newbalance.pt
#
#          Default Channel Grouping  Sessions  Pageviews
#   0                         Email       245        245
#   1                   Paid Search       245        735
#   2                Organic Search       245        245
#   3                        Direct       245        735
#   4                Organic Search       245        245
#   ...                         ...       ...        ...
#   165193              Paid Search        69        206
#   165194              Social Paid        52        120
#   165195           Organic Search        52         52
#   165196              Paid Search        86        309
#   165197              Social Paid        34         34
#
#   [165198 rows x 6 columns],
#   'NB | GA | TW':             Date Device Category                     Hostname  \
#   0     2016-11-30         desktop  www.newbalancetaiwan.com.tw
#   1     2016-11-30         desktop  www.newbalancetaiwan.com.tw
#   2     2016-11-30         desktop  www.newbalancetaiwan.com.tw
#   3     2016-11-30         desktop  www.newbalancetaiwan.com.tw
#   4     2016-11-30          mobile  www.newbalancetaiwan.com.tw
#   ...          ...             ...                          ...
#   32809 2022-12-31          tablet            newbalance.com.tw
#   32810 2022-12-31          tablet            newbalance.com.tw
#   32811 2022-12-31          tablet            newbalance.com.tw
#   32812 2022-12-31          tablet            newbalance.com.tw
#   32813 2022-12-31          tablet            newbalance.com.tw
#
#         Default Channel Grouping  Sessions  Pageviews
#   0                       Direct       170       1595
#   1               Organic Search       475       5870
#   2                     Referral       119       2172
#   3                       Social       136        746
#   4                       Direct       221       1086
#   ...                        ...       ...        ...
#   32809                  Display         4          9
#   32810           Organic Search        45        198
#   32811        Other Advertising         1          1
#   32812              Paid Search        61        288
#   32813                   Social         2          6
#
#   [32814 rows x 6 columns],
#   'NB | GA | HK':             Date Device Category               Hostname  \
#   0     2020-09-21         desktop  www.newbalance.com.hk
#   1     2020-09-21         desktop  www.newbalance.com.hk
#   2     2020-09-21         desktop  www.newbalance.com.hk
#   3     2020-09-21         desktop  www.newbalance.com.hk
#   4     2020-09-21         desktop  www.newbalance.com.hk
#   ...          ...             ...                    ...
#   16294 2022-12-31          tablet  www.newbalance.com.hk
#   16295 2022-12-31          tablet  www.newbalance.com.hk
#   16296 2022-12-31          tablet  www.newbalance.com.hk
#   16297 2022-12-31          tablet  www.newbalance.com.hk
#   16298 2022-12-31          tablet  www.newbalance.com.hk
#
#         Default Channel Grouping  Sessions  Pageviews
#   0                       Direct       210       1403
#   1                      Display        10         38
#   2               Organic Search       639       3263
#   3                  Paid Search       639       3664
#   4                     Referral       153        420
#   ...                        ...       ...        ...
#   16294                  Display         6          8
#   16295                    Email         1          1
#   16296           Organic Search        31        134
#   16297              Paid Search        46        214
#   16298                   Social         3          5
#
#   [16299 rows x 6 columns],
#   'NB | GA | MY':            Date Device Category               Hostname  \
#   0    2022-04-01         desktop  www.newbalance.com.my
#   1    2022-04-01         desktop  www.newbalance.com.my
#   2    2022-04-01         desktop  www.newbalance.com.my
#   3    2022-04-01          mobile  www.newbalance.com.my
#   4    2022-04-01          mobile  www.newbalance.com.my
#   ...         ...             ...                    ...
#   5107 2022-12-31          tablet  www.newbalance.com.my
#   5108 2022-12-31          tablet  www.newbalance.com.my
#   5109 2022-12-31          tablet  www.newbalance.com.my
#   5110 2022-12-31          tablet  www.newbalance.com.my
#   5111 2022-12-31          tablet  www.newbalance.com.my
#
#        Default Channel Grouping  Sessions  Pageviews
#   0                      Direct        26        146
#   1              Organic Search       185       1483
#   2                    Referral        49        276
#   3                      Direct        85        269
#   4              Organic Search       262       1244
#   ...                       ...       ...        ...
#   5107                  Display        77         90
#   5108           Organic Search        28        146
#   5109              Paid Search         3          3
#   5110                 Referral         2          5
#   5111                   Social         5          5
#
#   [5112 rows x 6 columns],
#   'NB | GA | SG':             Date Device Category               Hostname  \
#   0     2020-09-21         desktop  www.newbalance.com.sg
#   1     2020-09-21         desktop  www.newbalance.com.sg
#   2     2020-09-21         desktop  www.newbalance.com.sg
#   3     2020-09-21         desktop  www.newbalance.com.sg
#   4     2020-09-21         desktop  www.newbalance.com.sg
#   ...          ...             ...                    ...
#   16667 2022-12-31          tablet  www.newbalance.com.sg
#   16668 2022-12-31          tablet  www.newbalance.com.sg
#   16669 2022-12-31          tablet  www.newbalance.com.sg
#   16670 2022-12-31          tablet  www.newbalance.com.sg
#   16671 2022-12-31          tablet  www.newbalance.com.sg
#
#         Default Channel Grouping  Sessions  Pageviews
#   0                       Direct        51        305
#   1                      Display        36        170
#   2                        Email        16        487
#   3               Organic Search       226        930
#   4                  Paid Search       281       2106
#   ...                        ...       ...        ...
#   16667                   Direct        23         60
#   16668                  Display         2          2
#   16669           Organic Search        22         85
#   16670              Paid Search        24         80
#   16671                   Social        34         86
#
#   [16672 rows x 6 columns]}]

# %%
frames = [dict[region_code] for dict in raw for region_code in dict if region_code != 'Sheet1']
# raw = pd.concat(raw)

# %%
pd.concat(frames)
# Out:
#                       Date Device Category               Hostname  \
# 0      2016-11-30 00:00:00         desktop     www.newbalance.com
# 1      2016-11-30 00:00:00         desktop     www.newbalance.com
# 2      2016-11-30 00:00:00         desktop     www.newbalance.com
# 3      2016-11-30 00:00:00         desktop     www.newbalance.com
# 4      2016-11-30 00:00:00         desktop     www.newbalance.com
# ...                    ...             ...                    ...
# 16667  2022-12-31 00:00:00          tablet  www.newbalance.com.sg
# 16668  2022-12-31 00:00:00          tablet  www.newbalance.com.sg
# 16669  2022-12-31 00:00:00          tablet  www.newbalance.com.sg
# 16670  2022-12-31 00:00:00          tablet  www.newbalance.com.sg
# 16671  2022-12-31 00:00:00          tablet  www.newbalance.com.sg
#
#       Default Channel Grouping  Sessions  Pageviews
# 0                      (Other)      5282      25091
# 1                       Direct     22450     101023
# 2                      Display      7923      63387
# 3               Organic Search     17167     121492
# 4                  Paid Search      8584      69990
# ...                        ...       ...        ...
# 16667                   Direct        23         60
# 16668                  Display         2          2
# 16669           Organic Search        22         85
# 16670              Paid Search        24         80
# 16671                   Social        34         86
#
# [453621 rows x 6 columns]

# %%
raw
# Out:
#                       Date Device Category                      Hostname  \
# 0      2016-11-30 00:00:00         desktop            www.newbalance.com
# 1      2016-11-30 00:00:00         desktop            www.newbalance.com
# 2      2016-11-30 00:00:00         desktop            www.newbalance.com
# 3      2016-11-30 00:00:00         desktop            www.newbalance.com
# 4      2016-11-30 00:00:00         desktop            www.newbalance.com
# ...                    ...             ...                           ...
# 49640  2022-12-31 00:00:00          mobile  www.joesnewbalanceoutlet.com
# 49641  2022-12-31 00:00:00          mobile  www.joesnewbalanceoutlet.com
# 49642  2022-12-31 00:00:00          mobile  www.joesnewbalanceoutlet.com
# 49643  2022-12-31 00:00:00          tablet  www.joesnewbalanceoutlet.com
# 49644  2022-12-31 00:00:00          tablet  www.joesnewbalanceoutlet.com
#
#       Default Channel Grouping  Sessions  Pageviews
# 0                      (Other)      5282      25091
# 1                       Direct     22450     101023
# 2                      Display      7923      63387
# 3               Organic Search     17167     121492
# 4                  Paid Search      8584      69990
# ...                        ...       ...        ...
# 49640              Paid Search      4682      16516
# 49641                 Referral       260        390
# 49642                   Social       390       3121
# 49643                Affiliate       130        130
# 49644           Organic Search       260        260
#
# [217526 rows x 6 columns]

# %%
frames = [raw[region_code] for region_code in raw]
pd.concat(frames)
# Out:
#                       Date Device Category                      Hostname  \
# 0      2016-11-30 00:00:00         desktop            www.newbalance.com
# 1      2016-11-30 00:00:00         desktop            www.newbalance.com
# 2      2016-11-30 00:00:00         desktop            www.newbalance.com
# 3      2016-11-30 00:00:00         desktop            www.newbalance.com
# 4      2016-11-30 00:00:00         desktop            www.newbalance.com
# ...                    ...             ...                           ...
# 49640  2022-12-31 00:00:00          mobile  www.joesnewbalanceoutlet.com
# 49641  2022-12-31 00:00:00          mobile  www.joesnewbalanceoutlet.com
# 49642  2022-12-31 00:00:00          mobile  www.joesnewbalanceoutlet.com
# 49643  2022-12-31 00:00:00          tablet  www.joesnewbalanceoutlet.com
# 49644  2022-12-31 00:00:00          tablet  www.joesnewbalanceoutlet.com
#
#       Default Channel Grouping  Sessions  Pageviews
# 0                      (Other)      5282      25091
# 1                       Direct     22450     101023
# 2                      Display      7923      63387
# 3               Organic Search     17167     121492
# 4                  Paid Search      8584      69990
# ...                        ...       ...        ...
# 49640              Paid Search      4682      16516
# 49641                 Referral       260        390
# 49642                   Social       390       3121
# 49643                Affiliate       130        130
# 49644           Organic Search       260        260
#
# [217526 rows x 6 columns]

# %% [markdown]
# ## test functionality of pull_raw_traffic_data

# %%
raw = pull_raw_traffic_data(DATA_PATHS)

# %%
raw
# Out:
#            Device Category                      Hostname  \
# 2016-11-01          mobile  www.joesnewbalanceoutlet.com
# 2016-11-01          mobile  www.joesnewbalanceoutlet.com
# 2016-11-01         desktop  www.joesnewbalanceoutlet.com
# 2016-11-01         desktop  www.joesnewbalanceoutlet.com
# 2016-11-01         desktop  www.joesnewbalanceoutlet.com
# ...                    ...                           ...
# 2022-12-31          mobile             www.newbalance.ie
# 2022-12-31          mobile             www.newbalance.ie
# 2022-12-31          mobile             www.newbalance.ie
# 2022-12-31          mobile             www.newbalance.it
# 2022-12-31          tablet         www.newbalance.com.sg
#
#                Default Channel Grouping  Sessions  Pageviews
# 2016-11-01  Comparison Shopping Engines       130        130
# 2016-11-01                    Affiliate      2081      10924
# 2016-11-01                       Social       520       4031
# 2016-11-01                     Referral      1951      15085
# 2016-11-01                  Paid Search      2341       9103
# ...                                 ...       ...        ...
# 2022-12-31                     Referral        17         34
# 2022-12-31                       Social        17         86
# 2022-12-31                  Social Paid      2337       4314
# 2022-12-31                       Direct      1530       4743
# 2022-12-31                       Social        34         86
#
# [453621 rows x 5 columns]

# %% [markdown]
# ## test functionality of get_all_hostnames_from_df

# %%
hostnames = get_all_hostnames_from_df(raw)

# %%
len(hostnames)
# Out:
# 181

# %%
hostnames
# Out:
# ['(not set)',
#  '.campaign-archive.com',
#  '.campaign-archive1.com',
#  '.campaign-archive2.com',
#  '.list-manage.com',
#  '.list-manage1.com',
#  '.list-manage2.com',
#  '0919908622.com',
#  '0s.o53xo.nzsxoytbnrqw4y3ffzrgk.cmle.ru',
#  '0s.o53xo.nzsxoytbnrqw4y3ffzrw63i.cmle.ru',
#  '0s.o53xo.nzsxoytbnrqw4y3ffzrw63i.nblz.ru',
#  '0s.o53xo.nzsxoytbnrqw4y3ffzsgk.cmle.ru',
#  '0s.o53xo.nzsxoytbnrqw4y3ffzyhi.cmle.ru',
#  '162.158.77.204',
#  '172.p.syniva.es',
#  '23cz46qnadrxsspoarpvrenaau-achv5f5yelsuduq-newbalance-com-sg.translate.goog',
#  '23cz46qnadrxsspoarpvrenaau-fe3tvbk6lcbjw-www-newbalance-com-sg.translate.goog',
#  '3-letter-domains.net',
#  '52.221.27.57',
#  '59.125.33.72',
#  'andonymizersa.cf',
#  'aractidf.org',
#  'at.newbalance.eu',
#  'ccskin.com',
#  'champs-hualien.com.tw',
#  'charming911.com',
#  'click.linksynergy.com',
#  'cmttools.amazon.com',
#  'cool.sdfgrfgb119.cf',
#  'cz.newbalance.eu',
#  'damp-bush-182d.ahodayfa-el.workers.dev',
#  'deeprism.com',
#  'development-apac-newbalance.demandware.net',
#  'development.newbalance.com.au',
#  'development.newbalance.com.hk',
#  'dk.newbalance.eu',
#  'do-beta1.northpage.com',
#  'do.northpage.com',
#  'dphs.com.tw',
#  'ee.newbalance.eu',
#  'egek7vldulb2vyz3kyk5tt545u-adv7ofecxzh2qqi-newbalance-com-tw.translate.goog',
#  'epi-crawl-console-na.amazon.com',
#  'es.cerbe.com',
#  'fanyi.myyoudao.com',
#  'fcbakery.com.tw',
#  'fi.newbalance.eu',
#  'fr-newbalance.icims.com',
#  'googleadservices.com',
#  'houn.com.tw',
#  'hr.newbalance.eu',
#  'hxopbkvctqc6o5nk3ekg2qzbi4-jj2cvlaia66be-www-newbalance-com.translate.goog',
#  'intoren.com',
#  'jin-shau-ya.com',
#  'joesnewbalanceoutlet.beautypost.shopoglot.com',
#  'joesnewbalanceoutlet.litevpn.ru',
#  'jubilate.ffopsover7.ml',
#  'ks3v4xdqril5ggv7fqctgdzzva-fe3tvbk6lcbjw-www-newbalance-com-sg.translate.goog',
#  'kullanananlatiyor.review',
#  'lapmutasq.ga',
#  'localhost',
#  'localhost.newbalance.com',
#  'lt.newbalance.eu',
#  'lumei.tw',
#  'm.youtube.com',
#  'mail.acafa.com.tw',
#  'mail.idea-design.com.tw',
#  'mail.youdoweb.com.tw',
#  'match.zorosrv.com',
#  'mute-river-da6b.favoerdsjfh.workers.dev',
#  'nb-temp.dev.com',
#  'nb.dev.com',
#  'nbhk.dev.com',
#  'nbsg.dev.com',
#  'newbalance-tw.local',
#  'newbalance.ca',
#  'newbalance.co.nz',
#  'newbalance.co.uk',
#  'newbalance.com.au',
#  'newbalance.com.sg',
#  'newbalance.com.tw',
#  'newbalance.com.tw.googleweblight.com',
#  'newbalance.de',
#  'newbalance.dev.com',
#  'newbalance.es',
#  'newbalance.it',
#  'newbalance.litevpn.ru',
#  'newbalance.lv',
#  'newbalance.pt',
#  'newbalance.se',
#  'newbalance.us4.list-manage.com',
#  'nl.newbalance.eu',
#  'nn.ruheouwyrewrw.cf',
#  'nrucx5u45pxpjouwo4dmb3dldm-hw4pqoxzcs7yk-www-newbalance-com-sg.translate.goog',
#  'nrucx5u45pxpjouwo4dmb3dldm-jj2cvlaia66be-www-newbalance-com-sg.translate.goog',
#  'origin-www.joesnewbalanceoutlet.com',
#  'papago.naver.net',
#  'prod-nb-hk.monilab.net',
#  'prod.newbalance.com.tw',
#  'production-emea-newbalance.demandware.net',
#  'production-test-newbalanceathleticsinccorporate.demandware.net',
#  'production-web-newbalance.demandware.net',
#  'readmodel.m.sogou.com',
#  'red-kitchen.com.tw',
#  'robina.com.tw',
#  'samtoyou.ml',
#  'savrin.club.tw',
#  'shop.newbalance.eu',
#  'shopoglot.com',
#  'si.newbalance.eu',
#  'signlanguage.ccu.edu.tw',
#  'sitecheck.247-hosting.com',
#  'sleep321.com.tw',
#  'stage.newbalance.com.tw',
#  'syndyne.com.tw',
#  'translate.baiducontent.com',
#  'translate.googleusercontent.com',
#  'translated.turbopages.org',
#  'translatoruser.net',
#  'urwaydesign.com',
#  'us7.my-proxy.com',
#  'vogue.com.tw',
#  'webcache.googleusercontent.com',
#  'webproxy.to',
#  'weimingpharma.com.tw',
#  'wwv.east-dobo.com',
#  'www-joesnewbalanceoutlet-com.translate.goog',
#  'www-newbalance-co-uk.translate.goog',
#  'www-newbalance-com-tw.translate.goog',
#  'www-newbalance-com.translate.goog',
#  'www-newbalance-de.translate.goog',
#  'www.advertiser-checkout.com',
#  'www.amyusingi.ga',
#  'www.andonymizersa.cf',
#  'www.bigdata-domain.com',
#  'www.googleadservices.com',
#  'www.hamsterdance.com',
#  'www.hotspotshield.com',
#  'www.joesnewbalanceoutlet.com',
#  'www.joesnewbalanceoutlet.com.googleweblight.com',
#  'www.mallree.com',
#  'www.mattwpbs.com',
#  'www.nbls.cc',
#  'www.newbalance.be',
#  'www.newbalance.ca',
#  'www.newbalance.ca.googleweblight.com',
#  'www.newbalance.co.hu',
#  'www.newbalance.co.nz',
#  'www.newbalance.co.nz.googleweblight.com',
#  'www.newbalance.co.uk',
#  'www.newbalance.com',
#  'www.newbalance.com.au',
#  'www.newbalance.com.au.googleweblight.com',
#  'www.newbalance.com.googleweblight.com',
#  'www.newbalance.com.gr',
#  'www.newbalance.com.hk',
#  'www.newbalance.com.my',
#  'www.newbalance.com.sg',
#  'www.newbalance.com.tw',
#  'www.newbalance.de',
#  'www.newbalance.es',
#  'www.newbalance.es.googleweblight.com',
#  'www.newbalance.eu',
#  'www.newbalance.fr',
#  'www.newbalance.fr.googleweblight.com',
#  'www.newbalance.ie',
#  'www.newbalance.it',
#  'www.newbalance.lu',
#  'www.newbalance.lv',
#  'www.newbalance.pt',
#  'www.newbalance.se',
#  'www.newbalancetaiwan.com.tw',
#  'www.optimizelyedit.com',
#  'www.solmidoxi.tk',
#  'www.translatoruser-int.com',
#  'www.translatoruser.net',
#  'www.wearehapa.com',
#  'www.www.kproxy.com',
#  'www.youtube.com',
#  'www_newbalance_com.s.shopozavr.ru',
#  'xu4bfopwnn7fc4ezlbtjwao2i4-adwhj77lcyoafdy-www-newbalance-co-uk.translate.goog',
#  'yenstyle.com']

# %% [markdown]
# ## test functionality of get_hostname_data_from_df

# %%
wwwnewbalancecom = get_hostname_data_from_df(raw, SERIES_FREQ, 'www.newbalance.com')
# Out:
# /tmp/ipykernel_232/2777007201.py:24: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   hostname_daily_traffic.loc[:, 'Year'] = hostname_daily_traffic.index.year
# /tmp/ipykernel_232/2777007201.py:25: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   hostname_daily_traffic.loc[:, 'Month'] = hostname_daily_traffic.index.month
# /tmp/ipykernel_232/2777007201.py:26: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   hostname_daily_traffic.loc[:, 'Day'] = 1
# /tmp/ipykernel_232/2777007201.py:27: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   hostname_daily_traffic.loc[:, 'Date'] = pd.to_datetime(hostname_daily_traffic[['Year', 'Month', 'Day']])

# %%
wwwnewbalancecom
# Out:
#             Sessions  Pageviews
# Date
# 2016-12-01   3378004   23999244
# 2017-01-01   3360180   21827590
# 2017-02-01   3269727   22854333
# 2017-03-01   3927370   26801491
# 2017-04-01   3435448   23236627
# ...              ...        ...
# 2022-08-01  10958689   37023290
# 2022-09-01   9481649   31645979
# 2022-10-01  12059381   38057960
# 2022-11-01  13982720   46661380
# 2022-12-01  12356001   40385029
#
# [73 rows x 2 columns]

# %% [markdown]
# ## operations of dropping first row of pandasdataframe

# %%
wwwnewbalancecom.iloc[1:, :]
# Out:
#             Sessions  Pageviews
# Date
# 2016-12-01   3378004   23999244
# 2017-01-01   3360180   21827590
# 2017-02-01   3269727   22854333
# 2017-03-01   3927370   26801491
# 2017-04-01   3435448   23236627
# ...              ...        ...
# 2022-08-01  10958689   37023290
# 2022-09-01   9481649   31645979
# 2022-10-01  12059381   38057960
# 2022-11-01  13982720   46661380
# 2022-12-01  12356001   40385029
#
# [73 rows x 2 columns]
